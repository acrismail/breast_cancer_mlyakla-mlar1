# %% [markdown]
# <a href="https://colab.research.google.com/github/acrismail/breast_cancer_mlyakla-mlar1/blob/main/breast_cancer_mlyakla%C5%9F%C4%B1mlar.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## About Dataset
#
#
# This dataset of breast cancer patients was obtained from the 2017 November update of the SEER Program of the NCI, which provides information on population-based cancer statistics. The dataset involved female patients with infiltrating duct and lobular carcinoma breast cancer (SEER primary cites recode NOS histology codes 8522/3) diagnosed in 2006-2010. Patients with unknown tumour size, examined regional LNs, positive regional LNs, and patients whose survival months were less than 1 month were excluded; thus, 4024 patients were ultimately included.
#
# ## attributes
#
# Race: 0 = represent white Race , 1 = represent Black Race and 2 = Represent Other Race .
#
# Marital Status: 0 = Married, 1 = Divorced , 2= Single, 3 = Widowed and 4 = Separated
#
# T Stage: The T refers to the size and extent of the main tumor. The main tumor is usually called the primary tumor.T1, T2, T3, T4: Refers to the size and/or extent of the main tumor. The higher the number after the T, the larger the tumor or the more it has grown into nearby tissues. T-T0: No evidence of primary tumor. T1 (includes T1a, T1b, and T1c): Tumor is 2 cm (3/4 of an inch) or less across. T2: Tumor is more than 2 cm but not more than 5 cm (2 inches) across. T3: Tumor is more than 5 cm across
#
# N Stage: The main tumor is usually called the primary tumor. The N refers to the the number of nearby lymph nodes that have cancer. The M refers to whether the cancer has metastasized. This means that the cancer has spread from the primary tumor to other parts of the body.N1, N2, N3: Refers to the number and location of lymph nodes that contain cancer. The higher the number after the N, the more lymph nodes that contain cancer.
#
# 6th Stage: 0 = IIA , 1= IIIA, 2 = IIIC , 3=IIB and 4 = IIIB Stage groups for breast cancer,Doctors assign the stage of the cancer by combining the T, N, and M classifications (see above), the tumor grade, and the results of ER/PR and HER2 testing. This information is used to help determine your prognosis (see Diagnosis).Most patients are anxious to learn the exact stage of the cancer. If you have surgery as the first treatment for your cancer, your doctor will generally confirm the stage of the cancer when the testing after surgery is finalized, usually about 5 to 7 days after surgery. When systemic treatment is given before surgery, which is typically with medications and is called neoadjuvant therapy, the stage of the cancer is primarily determined clinically. Doctors may refer to stage I to stage IIA cancer as "early stage" and stage IIB to stage III as "locally advanced."
#
# Stage IIA Any 1 of these conditions:
#
# There is no evidence of a tumor in the breast, but the cancer has spread to 1 to 3 axillary lymph nodes. It has not spread to distant parts of the body (T0, N1, M0).
#
# The tumor is 20 mm or smaller and has spread to 1 to 3 axillary lymph nodes (T1, N1, M0).
# The tumor is larger than 20 mm but not larger than 50 mm and has not spread to the axillary lymph nodes (T2, N0, M0).
#
# Stage IIB Either of these conditions:
#
# The tumor is larger than 20 mm but not larger than 50 mm and has spread to 1 to 3 axillary lymph nodes (T2, N1, M0).
#
# The tumor is larger than 50 mm but has not spread to the axillary lymph nodes (T3, N0, M0).
#
# Stage IIIA The tumor of any size has spread to 4 to 9 axillary lymph nodes or to internal mammary lymph nodes. It has not spread to other parts of the body (T0, T1, T2, or T3; N2; M0). Stage IIIA may also be a tumor larger than 50 mm that has spread to 1 to 3 axillary lymph nodes (T3, N1, M0).
#
# Stage IIIB The tumor has spread to the chest wall or caused swelling or ulceration of the breast, or it is diagnosed as inflammatory breast cancer. It may or may not have spread to up to 9 axillary or internal mammary lymph nodes. It has not spread to other parts of the body (T4; N0, N1, or N2; M0).
#
# Stage IIIC A tumor of any size that has spread to 10 or more axillary lymph nodes, the internal mammary
# ymph nodes, and/or the lymph nodes under the collarbone. It has not spread to other parts of the body (any T, N3, M0).
#
# differentiate 0 =Poorly differentiated, 1 = Moderately differentiated, 2= Well differentiated and 3 = Undifferentiated
#
# Grade:
#
# What does cancer grade mean?
# Breast cancers are given a grade according to:
#
# 1.1 How different the cancer cells are to normal breast cells 1.2 How quickly they are growing
#
# The grade of a cancer is different to the cancer stage. A cancer’s grade is determined when a doctor (pathologist) looks at the cancer cells under a microscope, using tissue from a biopsy or after breast cancer surgery.
#
# * What are the different grades of breast cancer?
# There are three grades of invasive breast cancer:
#
# Grade 1 looks most like normal breast cells and is usually slow growing Grade 2 looks less like normal cells and is growing faster Grade 3 looks different to normal breast cells and is usually fast growing
#
# Or we can say that a low grade number (grade 1) usually means the cancer is slower-growing and less likely to spread. A high grade number (grade 3) means a faster-growing cancer that's more likely to spread. An intermediate grade number (grade 2) means the cancer is growing faster than a grade 1 cancer but slower than a grade 3 cancer.
#
# Sometimes the grade given to a cancer after a biopsy can change after surgery. This is because after surgery there’s more tissue for the pathologist to look at, which can give them more detailed information about the cancer.
#
# A Stage: 0 =Regional and 1 = Distant
# This parameters shows Stages of Cancer and is a summary of all data , it is an attribute that involves T,N and Grade data.
#
# Regional: The cancer has spread outside the breast to nearby structures or lymph nodes.
#
# Distant: The cancer has spread to distant parts of the body such as the lungs, liver or bones.
#
# Estrogen Status: 0 =Estrogen positive and 1 = Estrogen negative
#
# Estrogen positive : - Cancer cells that are ER positive may need estrogen to grow. These cells may stop growing or die when treated with substances that block the binding and actions of estrogen. Also called estrogen receptor positive.
# Estrogen negative : - negative breast cancers are a group of tumors with poor prognosis and fewer cancer prevention and treatment strategies compared to ER-positive tumors.
# Progesterone Status: 0 = Progesterone positive and 1 = Progesterone negative
#
# Progesterone positive:- This type of breast cancer is sensitive to progesterone, and the cells have receptors that allow them to use this hormone to grow. Treatment with endocrine therapy blocks the growth of the cancer cells.
#
# Progesterone negative: - This type of breast cancers have no estrogen or progesterone receptors. Treatment with hormone therapy drugs is not helpful for these cancers. These cancers tend to grow faster than hormone receptor-positive cancers.
#
# Status: 0 = Alive and 1 = dead
#
# Hormone receptor-negative (or hormone-negative): - breast cancers have no estrogen or progesterone receptors. Treatment with hormone therapy drugs is not helpful for these cancers. These cancers tend to grow faster than hormone receptor-positive cancers. If they come back after treatment, it’s often in the first few years
#
# ## Veri Kümesi Hakkında
#
# Meme kanseri hastalarına ilişkin bu veri seti, NCI'nin nüfusa dayalı kanser istatistikleri hakkında bilgi sağlayan SEER Programının 2017 Kasım güncellemesinden elde edilmiştir. Veri seti, 2006-2010'da teşhis edilen infiltre kanal ve lobüler karsinom meme kanseri (SEER birincil alıntıları NOS histoloji kodlarını 8522/3 olarak kodlar) olan kadın hastaları içermektedir. Tümör boyutu bilinmeyen, incelenen bölgesel LN'leri olan, pozitif bölgesel LN'leri olan ve sağkalım ayları 1 aydan az olan hastalar dışlandı; böylece 4024 hasta nihai olarak dahil edildi.
#
# ## öznitelikler
#
# Irk: 0 = Beyaz Irk'ı temsil eder, 1 = Siyah Irk'ı temsil eder ve 2 = Diğer Irk'ı temsil eder.
#
# Medeni Durumu: 0=Evli, 1=Boşanmış, 2=Bekar, 3=Dul ve 4=Ayrılmış
#
# T Aşaması: T, ana tümörün boyutunu ve kapsamını ifade eder. Ana tümöre genellikle birincil tümör denir.T1, T2, T3, T4: Ana tümörün boyutunu ve/veya yaygınlığını ifade eder. T'den sonraki sayı ne kadar yüksek olursa, tümör o kadar büyük veya yakın dokulara o kadar çok büyümüştür. T-T0: Primer tümör kanıtı yok. T1 (T1a, T1b ve T1c'yi içerir): Tümör 2 cm (3/4 inç) veya daha küçüktür. T2: Tümör 2 cm'den büyük ancak 5 cm'den (2 inç) büyük değil. T3: Tümör 5 cm'den büyük
#
# N Evresi: Ana tümöre genellikle birincil tümör denir. N, kansere sahip yakındaki lenf düğümlerinin sayısını ifade eder. M, kanserin metastaz yapıp yapmadığını ifade eder. Bu, kanserin birincil tümörden vücudun diğer bölgelerine yayıldığı anlamına gelir.N1,N2,N3: Kanser içeren lenf bezlerinin sayısını ve yerleşimini ifade eder. N'den sonraki sayı ne kadar yüksekse, kanser içeren lenf düğümleri o kadar fazladır.
#
# 6. Evre: 0 = IIA , 1= IIIA, 2 = IIIC , 3=IIB ve 4 = IIIB Meme kanseri için evre grupları, Doktorlar kanserin evresini T, N ve M sınıflandırmalarını birleştirerek atarlar (yukarıya bakın), tümör derecesi ve ER/PR ve HER2 testinin sonuçları. Bu bilgi prognozunuzu belirlemenize yardımcı olmak için kullanılır (bkz. Teşhis). Hastaların çoğu kanserin tam evresini öğrenmek konusunda endişelidir. Kanseriniz için ilk tedavi olarak ameliyat olduysanız, doktorunuz genellikle ameliyattan sonraki testler tamamlandığında, genellikle ameliyattan yaklaşık 5 ila 7 gün sonra kanserin evresini onaylayacaktır. Ameliyattan önce tipik olarak ilaçlarla yapılan ve neoadjuvan tedavi olarak adlandırılan sistemik tedavi verildiğinde, kanserin evresi öncelikle klinik olarak belirlenir. Doktorlar, evre I ila evre IIA kanserini "erken evre" ve evre IIB'den evre III'e "yerel olarak ileri" olarak adlandırabilirler.
#
# Aşama IIA Bu koşullardan herhangi biri:
#
# Memede bir tümör olduğuna dair bir kanıt yoktur, ancak kanser 1 ila 3 koltuk altı lenf düğümüne yayılmıştır. Vücudun uzak bölgelerine (T0, N1, M0) yayılmadı.
#
# Tümör 20 mm veya daha küçüktür ve 1 ila 3 koltuk altı lenf düğümüne (T1, N1, M0) yayılmıştır.
# Tümör 20 mm'den büyük ancak 50 mm'den büyük değil ve koltuk altı lenf düğümlerine (T2, N0, M0) yayılmadı.
#
# Aşama IIB Bu koşullardan herhangi biri:
#
# Tümör 20 mm'den büyük ancak 50 mm'den büyük değil ve 1 ila 3 koltuk altı lenf düğümüne (T2, N1, M0) yayılmış.
#
# Tümör 50 mm'den büyüktür ancak koltuk altı lenf düğümlerine (T3, N0, M0) yayılmamıştır.
#
# Evre IIIA Herhangi bir boyuttaki tümör, 4 ila 9 aksiller lenf düğümüne veya iç meme lenf düğümlerine yayılmıştır. Vücudun diğer bölgelerine yayılmadı (T0, T1, T2 veya T3; N2; M0). Evre IIIA, 1 ila 3 aksiller lenf düğümüne (T3, N1, M0) yayılmış, 50 mm'den büyük bir tümör de olabilir.
#
# Evre IIIB Tümör göğüs duvarına yayılmıştır veya memede şişlik veya ülserasyona neden olmuştur veya inflamatuar meme kanseri olarak teşhis edilmiştir. 9 koltuk altı veya iç meme lenf düğümüne kadar yayılmış olabilir veya olmayabilir. Vücudun diğer bölgelerine yayılmamıştır (T4; N0, N1 veya N2; M0).
#
# Evre IIIC 10 veya daha fazla koltuk altı lenf noduna, iç memeye yayılmış herhangi bir boyuttaki tümör
# ymph düğümleri ve/veya köprücük kemiği altındaki lenf düğümleri. Vücudun diğer bölgelerine yayılmamıştır (herhangi bir T, N3, M0).
#
# diferansiye 0 =Kötü diferansiye, 1=Orta derecede diferansiye, 2= İyi diferansiye ve 3=Farklılaşmamış
#
# Seviye:
#
# Kanser derecesi ne anlama geliyor?
# Meme kanserleri aşağıdakilere göre derecelendirilir:
#
# 1.1 Kanser hücrelerinin normal meme hücrelerinden ne kadar farklı olduğu 1.2 Ne kadar hızlı büyüyorlar
#
# Bir kanserin derecesi, kanserin evresinden farklıdır. Doktor (patolog), meme kanseri ameliyatından sonra veya biyopsiden alınan dokuyu kullanarak mikroskop altında kanser hücrelerine baktığında kanserin derecesi belirlenir.
#
# * Meme kanserinin farklı dereceleri nelerdir?
# İnvaziv meme kanserinin üç derecesi vardır:
#
# 1. Derece normal meme hücrelerine çok benziyor ve genellikle yavaş büyüyor 2. Derece normal hücrelere daha az benziyor ve daha hızlı büyüyor 3. Derece normal meme hücrelerinden farklı görünüyor ve genellikle hızlı büyüyor
#
# Veya düşük dereceli bir sayının (1. derece) genellikle kanserin daha yavaş büyüdüğü ve yayılma olasılığının düşük olduğu anlamına geldiğini söyleyebiliriz. Yüksek dereceli bir sayı (3. derece), yayılma olasılığı daha yüksek olan ve daha hızlı büyüyen bir kanser anlamına gelir. Orta dereceli bir sayı (2. derece), kanserin 1. derece kanserden daha hızlı, 3. derece kanserden daha yavaş büyüdüğü anlamına gelir.
#
# Bazen biyopsi sonrası kansere verilen derece ameliyattan sonra değişebilir. Bunun nedeni, ameliyattan sonra patoloğun bakacağı daha fazla doku olması ve bu da onlara kanser hakkında daha ayrıntılı bilgi verebilmesidir.
#
# A Aşaması: 0 =Bölgesel ve 1 = Uzak
# Bu parametreler Kanserin Evrelerini gösterir ve tüm verilerin bir özetidir, T,N ve Grade verilerini içeren bir özelliktir.
#
# Bölgesel: Kanser, memenin dışında yakındaki yapılara veya lenf düğümlerine yayılmıştır.
#
# Uzak: Kanser, akciğerler, karaciğer veya kemikler gibi vücudun uzak bölgelerine yayılmıştır.
#
# Östrojen Durumu: 0 = Östrojen pozitif ve 1 = Östrojen negatif
#
# Östrojen pozitif : - ER pozitif olan kanser hücrelerinin büyümesi için östrojene ihtiyacı olabilir. Bu hücreler, östrojenin bağlanmasını ve etkilerini bloke eden maddelerle tedavi edildiğinde büyümeyi durdurabilir veya ölebilir. Östrojen reseptörü pozitif olarak da adlandırılır.
# Östrojen negatif: - Negatif meme kanserleri, ER-pozitif tümörlere kıyasla kötü prognozlu ve daha az kanser önleme ve tedavi stratejileri olan bir grup tümördür.
# Progesteron Durumu: 0 = Progesteron pozitif ve 1 = Progesteron negatif
#
# Progesteron pozitif: - Bu tür meme kanseri progesterona duyarlıdır ve hücrelerin büyümek için bu hormonu kullanmalarına izin veren reseptörleri vardır. Endokrin tedavisi ile tedavi, kanser hücrelerinin büyümesini engeller.
#
# Progesteron negatif: - Bu tip meme kanserlerinde östrojen veya progesteron reseptörü yoktur. Hormon tedavisi ilaçları ile tedavi bu kanserler için yararlı değildir. Bu kanserler, hormon reseptörü pozitif kanserlerden daha hızlı büyüme eğilimindedir.
#
# Durum: 0 = Canlı ve 1 = ölü
#
# Hormon reseptörü negatif (veya hormon negatif): - meme kanserlerinde östrojen veya progesteron reseptörü yoktur. Hormon tedavisi ilaçları ile tedavi bu kanserler için yararlı değildir. Bu kanserler, hormon reseptörü pozitif kanserlerden daha hızlı büyüme eğilimindedir. Tedaviden sonra geri gelirlerse, genellikle ilk birkaç yıl içindedir.

# %% [markdown]
# ## Analysis Content
# * 1.[Python Libraries](#1)
# * 2.[data loading](#2)
# * 3.[EDA](#3)
# * 4.[data Preprocessing](#4)
# * 5.[Modelling](#5)
# * 6.[Randomforest](#6)
# * 7.[xgboost](#7)

# %% [markdown]
# <a id="1"></a>
# ## 1.Python Libraries

# %%
import numpy as np 
import pandas as pd
import seaborn as sns
import statsmodels.api as sm
from sklearn.model_selection import train_test_split,GridSearchCV,cross_val_score
from sklearn.metrics import confusion_matrix,accuracy_score,classification_report
import matplotlib.pyplot as plt
import plotly.express as px
import missingno as msno
from sklearn.preprocessing import scale,StandardScaler
from sklearn import model_selection
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.neural_network import MLPClassifier
from sklearn.ensemble import RandomForestClassifier,AdaBoostClassifier
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.svm import SVC
from sklearn.naive_bayes import BernoulliNB,MultinomialNB
from sklearn.model_selection import KFold
import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# <a id="2"></a>
#
# ## 2.Data Loading

# %%
data=pd.read_csv("/content/Breast_Cancer.csv")
data.head()
# Out:
#    Age   Race Marital Status T Stage  N Stage 6th Stage  \
# 0   68  White        Married       T1      N1       IIA
# 1   50  White        Married       T2      N2      IIIA
# 2   58  White       Divorced       T3      N3      IIIC
# 3   58  White        Married       T1      N1       IIA
# 4   47  White        Married       T2      N1       IIB
#
#                differentiate Grade   A Stage  Tumor Size Estrogen Status  \
# 0      Poorly differentiated     3  Regional           4        Positive
# 1  Moderately differentiated     2  Regional          35        Positive
# 2  Moderately differentiated     2  Regional          63        Positive
# 3      Poorly differentiated     3  Regional          18        Positive
# 4      Poorly differentiated     3  Regional          41        Positive
#
#   Progesterone Status  Regional Node Examined  Reginol Node Positive  \
# 0            Positive                      24                      1
# ...

# %%
data.tail()
# Out:
#       Age   Race Marital Status T Stage  N Stage 6th Stage  \
# 4019   62  Other        Married       T1      N1       IIA
# 4020   56  White       Divorced       T2      N2      IIIA
# 4021   68  White        Married       T2      N1       IIB
# 4022   58  Black       Divorced       T2      N1       IIB
# 4023   46  White        Married       T2      N1       IIB
#
#                   differentiate Grade   A Stage  Tumor Size Estrogen Status  \
# 4019  Moderately differentiated     2  Regional           9        Positive
# 4020  Moderately differentiated     2  Regional          46        Positive
# 4021  Moderately differentiated     2  Regional          22        Positive
# 4022  Moderately differentiated     2  Regional          44        Positive
# 4023  Moderately differentiated     2  Regional          30        Positive
#
#      Progesterone Status  Regional Node Examined  Reginol Node Positive  \
# 4019            Positive                       1                      1
# ...

# %%
df=data.copy()
df.head()
# Out:
#    Age   Race Marital Status T Stage  N Stage 6th Stage  \
# 0   68  White        Married       T1      N1       IIA
# 1   50  White        Married       T2      N2      IIIA
# 2   58  White       Divorced       T3      N3      IIIC
# 3   58  White        Married       T1      N1       IIA
# 4   47  White        Married       T2      N1       IIB
#
#                differentiate Grade   A Stage  Tumor Size Estrogen Status  \
# 0      Poorly differentiated     3  Regional           4        Positive
# 1  Moderately differentiated     2  Regional          35        Positive
# 2  Moderately differentiated     2  Regional          63        Positive
# 3      Poorly differentiated     3  Regional          18        Positive
# 4      Poorly differentiated     3  Regional          41        Positive
#
#   Progesterone Status  Regional Node Examined  Reginol Node Positive  \
# 0            Positive                      24                      1
# ...

# %% [markdown]
# <a id="3"></a>
#
# ## 3.EDA

# %%
df.shape
# Out:
# (4024, 16)

# %%
#verisetimiz 4824 gözlem ve 16 öznitelikten oluşmaktadır
#Our dataset consists of 4824 observations and 16 features.

# %%
df.columns
# Out:
# Index(['Age', 'Race', 'Marital Status', 'T Stage ', 'N Stage', '6th Stage',
#        'differentiate', 'Grade', 'A Stage', 'Tumor Size', 'Estrogen Status',
#        'Progesterone Status', 'Regional Node Examined',
#        'Reginol Node Positive', 'Survival Months', 'Status'],
#       dtype='object')

# %%
#kolonları düzeltelim,(görünümü )
#fix the colons,(view)

# %%
df.columns=df.columns.str.replace(" ","_").str.lower()

# %%
df.columns
# Out:
# Index(['age', 'race', 'marital_status', 't_stage_', 'n_stage', '6th_stage',
#        'differentiate', 'grade', 'a_stage', 'tumor_size', 'estrogen_status',
#        'progesterone_status', 'regional_node_examined',
#        'reginol_node_positive', 'survival_months', 'status'],
#       dtype='object')

# %%
df.columns=df.columns.str.strip("_")
df.columns
# Out:
# Index(['age', 'race', 'marital_status', 't_stage', 'n_stage', '6th_stage',
#        'differentiate', 'grade', 'a_stage', 'tumor_size', 'estrogen_status',
#        'progesterone_status', 'regional_node_examined',
#        'reginol_node_positive', 'survival_months', 'status'],
#       dtype='object')

# %%
#tüm kolonları önce küçük harflere dönüştürdük sonra boşluklar yerine "_" işaretini ekledik
#we converted all columns to lowercase letters and then added the "_" sign instead of spaces

# %%
#structural information

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4024 entries, 0 to 4023
# Data columns (total 16 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   age                     4024 non-null   int64
#  1   race                    4024 non-null   object
#  2   marital_status          4024 non-null   object
#  3   t_stage                 4024 non-null   object
#  4   n_stage                 4024 non-null   object
#  5   6th_stage               4024 non-null   object
#  6   differentiate           4024 non-null   object
#  7   grade                   4024 non-null   object
#  8   a_stage                 4024 non-null   object
#  9   tumor_size              4024 non-null   int64
#  10  estrogen_status         4024 non-null   object
#  11  progesterone_status     4024 non-null   object
#  12  regional_node_examined  4024 non-null   int64
#  13  reginol_node_positive   4024 non-null   int64
# ...

# %%
# verisetimizde 5 sayısal ,11 kategorik değişken var
# there are 5 numeric and 11 categorical variables in our dataset

# %%
# summary statistical

df.describe().T
# Out:
#                          count  mean   std   min   25%   50%   75%    max
# age                    4024.00 53.97  8.96 30.00 47.00 54.00 61.00  69.00
# tumor_size             4024.00 30.47 21.12  1.00 16.00 25.00 38.00 140.00
# regional_node_examined 4024.00 14.36  8.10  1.00  9.00 14.00 19.00  61.00
# reginol_node_positive  4024.00  4.16  5.11  1.00  1.00  2.00  5.00  46.00
# survival_months        4024.00 71.30 22.92  1.00 56.00 73.00 90.00 107.00

# %%
df.race.value_counts()
# Out:
# White    3413
# Other     320
# Black     291
# Name: race, dtype: int64

# %%
#en fazla bulunan ırk beyaz
#most common race is white

# %%
df.marital_status.value_counts()  #medeni durumu
# Out:
# Married      2643
# Single        615
# Divorced      486
# Widowed       235
# Separated      45
# Name: marital_status, dtype: int64

# %%
# medeni durumu 5 gruba ayrılmış(evli,bekar,boşanmış,dul,ayrılmış) enfazla bulunan grup evli
# marital status divided into 5 groups (married, single, divorced, widowed, separated)

# %%
df.t_stage.value_counts()
# Out:
# T2    1786
# T1    1603
# T3     533
# T4     102
# Name: t_stage, dtype: int64

# %%
# en büyük olan tumor T4,en küçük olan T1( hastalar en fazla T2 tümoruna sahip,normal)
# largest tumor T4, smallest T1 (patients have the most T2 tumors, normal)

# %%
df.n_stage.value_counts()
# Out:
# N1    2732
# N2     820
# N3     472
# Name: n_stage, dtype: int64

# %%
# N3 hücresinde kanser en fazla,N1 de kanser hücresi en az (büyük çoğunluk N1)
# N3 cell has the most cancer, N1 has the least cancer cell (majority N1)

# %%
df["6th_stage"].value_counts()
# Out:
# IIA     1305
# IIB     1130
# IIIA    1050
# IIIC     472
# IIIB      67
# Name: 6th_stage, dtype: int64

# %%
#IIIB Meme kanseri için evre grupları
#IIIB Stage groups for breast cancer

# %%
df.grade.value_counts()
# Out:
# 2                        2351
# 3                        1111
# 1                         543
#  anaplastic; Grade IV      19
# Name: grade, dtype: int64

# %%
# kanser dereceleri 3 türde oluşuyor
# cancer grades consist of 3 types

# %%
df.a_stage.value_counts()
# Out:
# Regional    3932
# Distant       92
# Name: a_stage, dtype: int64

# %% [markdown]
# Regional: Cancer has spread outside the breast to nearby structures or lymph nodes.
# Distant: Cancer has spread to distant parts of the body, such as the lungs, liver, or bones.
#
#
# Bölgesel: Kanser, memenin dışında yakındaki yapılara veya lenf düğümlerine yayılmıştır.
# Uzak: Kanser, akciğerler, karaciğer veya kemikler gibi vücudun uzak bölgelerine yayılmıştır.

# %% [markdown]
# * kanser bazı hastalarda derin yayılmış(akciğer,karaciğer vs)çoğunda bölgesel yayılmış
# * Cancer has spread deep in some patients (lung, liver, etc.)

# %%
df.estrogen_status.value_counts()
# Out:
# Positive    3755
# Negative     269
# Name: estrogen_status, dtype: int64

# %%
# ostrojen durunu en fazka pozitif
# estrogen status is the most positive

# %%
df.differentiate.value_counts()
# Out:
# Moderately differentiated    2351
# Poorly differentiated        1111
# Well differentiated           543
# Undifferentiated               19
# Name: differentiate, dtype: int64

# %%
df.progesterone_status.value_counts()
# Out:
# Positive    3326
# Negative     698
# Name: progesterone_status, dtype: int64

# %% [markdown]
# Progesteron pozitif: - Bu tür meme kanseri progesterona duyarlıdır ve hücrelerin büyümek için bu hormonu kullanmalarına izin veren reseptörleri vardır. Endokrin tedavisi ile tedavi, kanser hücrelerinin büyümesini engeller.
# Progesteron negatif: - Bu tip meme kanserlerinde östrojen veya progesteron reseptörü yoktur. Hormon tedavisi ilaçları ile tedavi bu kanserler için yararlı değildir. Bu kanserler, hormon reseptörü pozitif kanserlerden daha hızlı büyüme eğilimindedir.
#
# Progesterone positive: - This type of breast cancer is sensitive to progesterone and cells have receptors that allow them to use this hormone to grow. Treatment with endocrine therapy inhibits the growth of cancer cells.
# Progesterone negative: - This type of breast cancer has no estrogen or progesterone receptors. Treatment with hormone therapy drugs is not helpful for these cancers. These cancers tend to grow faster than hormone receptor positive cancers.

# %%
df.status.value_counts()
# Out:
# Alive    3408
# Dead      616
# Name: status, dtype: int64

# %%
# ölen ve hayatta kalan
# deceased and surviving

# %%
# yaşı en büyük ve en küçük olan hastaları gözlemleyelim
# observe the oldest and youngest patients

# %%
df.sort_values("age",ascending=False).head(20) #oldest
# Out:
#       age   race marital_status t_stage n_stage 6th_stage  \
# 2679   69  White        Married      T1      N1       IIA
# 3854   69  White        Married      T1      N2      IIIA
# 1822   69  White        Married      T2      N1       IIB
# 1816   69  White        Married      T1      N1       IIA
# 1814   69  White        Widowed      T2      N1       IIB
# 1795   69  White        Widowed      T1      N1       IIA
# 2945   69  White        Widowed      T2      N1       IIB
# 2334   69  White        Widowed      T3      N3      IIIC
# 3503   69  White       Divorced      T3      N1      IIIA
# 2339   69  White        Single       T4      N3      IIIC
# 155    69  White        Widowed      T3      N2      IIIA
# 1740   69  White        Married      T1      N1       IIA
# 2355   69  White        Married      T3      N1      IIIA
# 1720   69  White        Married      T1      N1       IIA
# 2789   69  Black       Divorced      T2      N3      IIIC
# ...

# %%
df.sort_values("age").head(20)  #youngest
# Out:
#       age   race marital_status t_stage n_stage 6th_stage  \
# 702    30  White        Single       T2      N2      IIIA
# 938    30  White       Divorced      T3      N2      IIIA
# 1544   30  White        Married      T1      N1       IIA
# 1888   30  White        Single       T2      N1       IIB
# 3310   30  Other        Married      T2      N1       IIB
# 848    31  White        Married      T2      N1       IIB
# 864    31  Other       Divorced      T2      N1       IIB
# 1320   31  White        Married      T3      N3      IIIC
# 4000   31  White       Divorced      T2      N1       IIB
# 1668   31  Other        Married      T3      N1      IIIA
# 1143   31  White       Divorced      T2      N1       IIB
# 1755   31  White        Single       T3      N2      IIIA
# 998    31  Other        Single       T1      N1       IIA
# 3711   31  Black        Single       T2      N2      IIIA
# 72     31  Black        Married      T2      N1       IIB
# ...

# %%
# en genç ölen hasta 30,en yaşlı ölen hasta 69 yaşta
# youngest deceased patient 30, oldest deceased patient 69 years old

# %%
# medeni durumuna göre işlem yapalım;
# let's deal with marital status;

# %%
df.groupby("marital_status")["age"].describe().T
# Out:
# marital_status    Divorced      Married  Separated     Single      Widowed
# count           486.000000  2643.000000  45.000000  615.000000  235.000000
# mean             55.131687    53.639803  51.533333   51.778862   61.519149
# std               8.342609     8.843519   7.881509    9.169764    6.825250
# min              30.000000    30.000000  37.000000   30.000000   37.000000
# 25%              49.000000    47.000000  46.000000   46.000000   58.000000
# 50%              56.000000    54.000000  53.000000   51.000000   63.000000
# 75%              61.000000    61.000000  57.000000   59.000000   67.000000
# max              69.000000    69.000000  67.000000   69.000000   69.000000

# %%
df.groupby("marital_status")["tumor_size"].describe().T
# Out:
# marital_status    Divorced      Married  Separated     Single      Widowed
# count           486.000000  2643.000000  45.000000  615.000000  235.000000
# mean             31.644033    30.045403  30.222222   31.243902   30.902128
# std              21.997442    21.204142  19.866473   20.200357   20.917292
# min               3.000000     1.000000   2.000000    2.000000    2.000000
# 25%              17.000000    15.000000  19.000000   18.000000   17.000000
# 50%              25.000000    24.000000  25.000000   25.000000   25.000000
# 75%              38.000000    37.000000  40.000000   40.000000   40.000000
# max             140.000000   140.000000  90.000000  130.000000  120.000000

# %% [markdown]
# <a id="4"></a>
#
# ## 4.Data Preprocessing

# %%
#missing value query

df.isna().sum()
# Out:
# age                       0
# race                      0
# marital_status            0
# t_stage                   0
# n_stage                   0
# 6th_stage                 0
# differentiate             0
# grade                     0
# a_stage                   0
# tumor_size                0
# estrogen_status           0
# progesterone_status       0
# regional_node_examined    0
# reginol_node_positive     0
# survival_months           0
# status                    0
# dtype: int64

# %%
# verisetinde eksik değer yok
# dataset has no missing values

# %%
#sayısal ve kategorik değişkenlerin için birer liste oluşturalım
#Let's create a list for your numeric and categorical variables

# %%
cat_list=[]
num_list=[]

for i in df.columns:
    unique_val=len(df[i].unique())
    
    if unique_val<10:
        cat_list.append(i)
    else:
        num_list.append(i)

# %%
cat_list
# Out:
# ['race',
#  'marital_status',
#  't_stage',
#  'n_stage',
#  '6th_stage',
#  'differentiate',
#  'grade',
#  'a_stage',
#  'estrogen_status',
#  'progesterone_status',
#  'status']

# %%
num_list
# Out:
# ['age',
#  'tumor_size',
#  'regional_node_examined',
#  'reginol_node_positive',
#  'survival_months']

# %%
#11 kategorik,5 sayısal değişkenden oluşuyor
#11 categorical, consists of 5 numeric variables

# %%
#şimdi sayısal değişkenlerimizin dağılım durumlarına bakalım;
#now let's look at the distribution of our numerical variables;

# %%
k=1
plt.figure(figsize=(12,12))
plt.tight_layout()
plt.suptitle("distribution of numerical values")


for i in df.loc[:,num_list]:
    plt.subplot(3,2,k)    
    sns.distplot(df[i])
    plt.title(i)
    k+=1

# %%
# tüm dağılımlar çarpık durumda
# all distributions are skewed

# %% [markdown]
# ## Outlier Problem

# %%
# tüm dağılımlar çarpık durumda,boxplot tekniği ile aykırı değer analizi yapalım;
# all distributions are skewed, let's do outlier analysis with boxplot technique;

# %%
for i in df.loc[:,num_list]:
    Q1 = df[i].quantile(0.25)
    Q3 = df[i].quantile(0.75)
    IQR = Q3-Q1
    up = Q3 + 1.5*IQR
    low = Q1 - 1.5*IQR

    if df[(df[i] > up) | (df[i] < low)].any(axis=None):
        print(i,"yes")
    else:
        print(i, "no")
# Out:
# age no
# tumor_size yes
# regional_node_examined yes
# reginol_node_positive yes
# survival_months yes

# %%
#dağılımları inceleyelim
# let's examine the distributions

# %%
df.loc[:,num_list].describe().T
# Out:
#                          count  mean   std   min   25%   50%   75%    max
# age                    4024.00 53.97  8.96 30.00 47.00 54.00 61.00  69.00
# tumor_size             4024.00 30.47 21.12  1.00 16.00 25.00 38.00 140.00
# regional_node_examined 4024.00 14.36  8.10  1.00  9.00 14.00 19.00  61.00
# reginol_node_positive  4024.00  4.16  5.11  1.00  1.00  2.00  5.00  46.00
# survival_months        4024.00 71.30 22.92  1.00 56.00 73.00 90.00 107.00

# %%
k=1
plt.figure(figsize=(10,10))
plt.suptitle("Distribution of Outliers")
plt.tight_layout()

for i in df.loc[:,num_list]:
    plt.subplot(3,2,k)
    sns.boxplot(x = i, data = df.loc[:,num_list])
    plt.title(i)
    k+=1

# %%
# aykırı değerleri gidermeyelim,bazı durumlar hakkında net bir çıkarım yok
# let's not remove outliers, I don't have a clear inference about some cases

# %% [markdown]
# ## Data Visualize

# %%
#categorical analysis

for i in cat_list:
    
    plt.figure(figsize=(10,10))
    sns.countplot(x=i,data=df.loc[:,cat_list])
    plt.title(i)

# %%
#numerical analysis

sns.pairplot(df.loc[:,num_list]);

# %%
#histogram

df.hist(figsize=(9,9));

# %%
plt.figure(figsize=(15,15))
plt.subplot(3,3,1)
sns.scatterplot(x ='tumor_size',y ='age',hue="marital_status",data = df)
plt.subplot(3,3,2)
sns.scatterplot(x ='tumor_size',y ='age',hue="status",data = df)
plt.subplot(3,3,3)
sns.boxplot(x="a_stage",y="tumor_size",hue="status",data=df)
plt.subplot(3,3,4)
sns.boxplot(x="a_stage",y="age",hue="marital_status",data=df)
plt.subplot(3,3,5)
sns.barplot(x="grade",y="tumor_size",hue="status",data=df)
plt.subplot(3,3,6)
sns.barplot(x="grade",y="survival_months",hue="status",data=df)
plt.subplot(3,3,7)
sns.barplot(x="6th_stage",y="survival_months",hue="status",data=df)
plt.subplot(3,3,8)
sns.barplot(x="6th_stage",y="tumor_size",hue="status",data=df)
plt.subplot(3,3,9)
sns.violinplot(x="n_stage",y="survival_months",hue="status",data=df)
plt.show()

# %% [markdown]
# ## Encoding

# %%
from sklearn.preprocessing import LabelEncoder

# %%
le=LabelEncoder()

# %%
df["N_race"]=le.fit_transform(df["race"])
df["N_marital_status"]=le.fit_transform(df["marital_status"])
df["N_t_stage"]=le.fit_transform(df["t_stage"])
df["N_n_stage"]=le.fit_transform(df["n_stage"])
df["N_6th_stage"]=le.fit_transform(df["6th_stage"])
df["N_differentiate"]=le.fit_transform(df["differentiate"])
df["N_a_stage"]=le.fit_transform(df["a_stage"])
df["N_estrogen_status"]=le.fit_transform(df["estrogen_status"])
df["N_progesterone_status"]=le.fit_transform(df["progesterone_status"])
df["N_status"]=le.fit_transform(df["status"])

# %%
df.head(3)
# Out:
#    age   race marital_status t_stage n_stage 6th_stage  \
# 0   68  White        Married      T1      N1       IIA
# 1   50  White        Married      T2      N2      IIIA
# 2   58  White       Divorced      T3      N3      IIIC
#
#                differentiate grade   a_stage  tumor_size  ... N_race  \
# 0      Poorly differentiated     3  Regional           4  ...      2
# 1  Moderately differentiated     2  Regional          35  ...      2
# 2  Moderately differentiated     2  Regional          63  ...      2
#
#   N_marital_status  N_t_stage  N_n_stage  N_6th_stage N_differentiate  \
# 0                1          0          0            0               1
# 1                1          1          1            2               0
# 2                0          2          2            4               0
#
#    N_a_stage  N_estrogen_status  N_progesterone_status  N_status
# 0          1                  1                      1         0
# ...

# %%
df.drop(["race","marital_status","t_stage","n_stage","6th_stage","differentiate",
         "a_stage","estrogen_status","progesterone_status","status"],axis=1,inplace=True)

# %%
df.head()
# Out:
#    age grade  tumor_size  regional_node_examined  reginol_node_positive  \
# 0   68     3           4                      24                      1
# 1   50     2          35                      14                      5
# 2   58     2          63                      14                      7
# 3   58     3          18                       2                      1
# 4   47     3          41                       3                      1
#
#    survival_months  N_race  N_marital_status  N_t_stage  N_n_stage  \
# 0               60       2                 1          0          0
# 1               62       2                 1          1          1
# 2               75       2                 0          2          2
# 3               84       2                 1          0          0
# 4               50       2                 1          1          0
#
#    N_6th_stage  N_differentiate  N_a_stage  N_estrogen_status  \
# 0            0                1          1                  1
# ...

# %%
#string değerleri sayısala dönüştürdük

# %% [markdown]
# ## Corelation Analysis

# %%
plt.figure(figsize=(12,12))
sns.heatmap(df.corr(),fmt=".2f",annot=True,linewidths=0.7,cmap="coolwarm")
plt.show()

# %%
cor=df.corr()["N_status"].sort_values(ascending=False)
pd.DataFrame({"column":cor.index,"Correlation with a":cor.values})
# Out:
#                     column  Correlation with a
# 0                 N_status                1.00
# 1              N_6th_stage                0.26
# 2    reginol_node_positive                0.26
# 3                N_n_stage                0.26
# 4                N_t_stage                0.15
# 5               tumor_size                0.13
# 6                      age                0.06
# 7   regional_node_examined                0.03
# 8         N_marital_status                0.03
# 9          N_differentiate               -0.02
# 10                  N_race               -0.05
# 11               N_a_stage               -0.10
# 12   N_progesterone_status               -0.18
# 13       N_estrogen_status               -0.18
# 14         survival_months               -0.48

# %%
# bir kaç teknik kullanacğım ,verisetinin birkaç kopyasını alalım
# i will use a few techniques, let's make a few copies of the dataset

# %%
df2=df.copy()

# %%
df2.head()
# Out:
#    age grade  tumor_size  regional_node_examined  reginol_node_positive  \
# 0   68     3           4                      24                      1
# 1   50     2          35                      14                      5
# 2   58     2          63                      14                      7
# 3   58     3          18                       2                      1
# 4   47     3          41                       3                      1
#
#    survival_months  N_race  N_marital_status  N_t_stage  N_n_stage  \
# 0               60       2                 1          0          0
# 1               62       2                 1          1          1
# 2               75       2                 0          2          2
# 3               84       2                 1          0          0
# 4               50       2                 1          1          0
#
#    N_6th_stage  N_differentiate  N_a_stage  N_estrogen_status  \
# 0            0                1          1                  1
# ...

# %%
df3=df.copy()
df3.head()
# Out:
#    age grade  tumor_size  regional_node_examined  reginol_node_positive  \
# 0   68     3           4                      24                      1
# 1   50     2          35                      14                      5
# 2   58     2          63                      14                      7
# 3   58     3          18                       2                      1
# 4   47     3          41                       3                      1
#
#    survival_months  N_race  N_marital_status  N_t_stage  N_n_stage  \
# 0               60       2                 1          0          0
# 1               62       2                 1          1          1
# 2               75       2                 0          2          2
# 3               84       2                 1          0          0
# 4               50       2                 1          1          0
#
#    N_6th_stage  N_differentiate  N_a_stage  N_estrogen_status  \
# 0            0                1          1                  1
# ...

# %%
df.corr()["N_status"].sort_values().plot(kind="bar");

# %% [markdown]
# <a id="5"></a>
#
# ## 5.Modelling

# %%
# 1.verisetinin  yapısını bozmadan modellerimizi karşılaştıralım
# Let's compare our models without breaking the structure of the 1st dataset.

# %%
X=df.drop("N_status",axis=1)
y=df["N_status"]

# %%
#train-test split

X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.3,random_state=3)

# %%
# !pip install lazypredict

# %%
from lazypredict.Supervised import LazyClassifier

# %%
clf= LazyClassifier(verbose=0,ignore_warnings=False, custom_metric=None )
models,predictions = clf.fit(X_train, X_test, y_train, y_test)
# Out:
#  21%|██        | 6/29 [00:02<00:07,  3.18it/s]
# CategoricalNB model failed to execute
# Negative values in data passed to CategoricalNB (input X)
#  69%|██████▉   | 20/29 [00:09<00:02,  3.21it/s]
# NuSVC model failed to execute
# specified nu is infeasible
#  90%|████████▉ | 26/29 [00:12<00:01,  2.08it/s]
# StackingClassifier model failed to execute
# __init__() missing 1 required positional argument: 'estimators'
# 100%|██████████| 29/29 [00:13<00:00,  2.16it/s]

# %%
models
# Out:
#                                Accuracy  Balanced Accuracy  ROC AUC  F1 Score  \
# Model
# Perceptron                         0.85               0.75     0.75      0.86
# NearestCentroid                    0.78               0.74     0.74      0.81
# AdaBoostClassifier                 0.90               0.72     0.72      0.89
# PassiveAggressiveClassifier        0.88               0.72     0.72      0.87
# XGBClassifier                      0.91               0.71     0.71      0.90
# LinearDiscriminantAnalysis         0.90               0.71     0.71      0.89
# RandomForestClassifier             0.91               0.71     0.71      0.90
# LogisticRegression                 0.90               0.70     0.70      0.89
# LGBMClassifier                     0.90               0.70     0.70      0.89
# CalibratedClassifierCV             0.90               0.70     0.70      0.89
# LinearSVC                          0.90               0.69     0.69      0.89
# ...

# %%
# en yüksek başarı oranını %91 olarak verdi,optimizasyon işlemiyle bu durum iyileştirilebilir
# gave the highest success rate of 91%, this can be improved with optimization

# %%
#2.yaklaşım korelasyonları yüksek olan atıp modelleri test edelim;
#2. Let's test the models with high approximation correlations;

# %%
df2.drop(["N_n_stage","tumor_size"],axis=1,inplace=True)

# %%
X2=df2.drop("N_status",axis=1)
y2=df2["N_status"]

# %%
#train-test split

X_train,X_test,y_train,y_test=train_test_split(X2,y2,test_size=0.3,random_state=3)

# %%
clf= LazyClassifier(verbose=0,ignore_warnings=False, custom_metric=None )
models2,predictions = clf.fit(X_train, X_test, y_train, y_test)
# Out:
#  21%|██        | 6/29 [00:01<00:04,  4.93it/s]
# CategoricalNB model failed to execute
# Negative values in data passed to CategoricalNB (input X)
#  69%|██████▉   | 20/29 [00:04<00:01,  5.90it/s]
# NuSVC model failed to execute
# specified nu is infeasible
#  90%|████████▉ | 26/29 [00:06<00:00,  3.65it/s]
# StackingClassifier model failed to execute
# __init__() missing 1 required positional argument: 'estimators'
# 100%|██████████| 29/29 [00:07<00:00,  3.96it/s]

# %%
models2
# Out:
#                                Accuracy  Balanced Accuracy  ROC AUC  F1 Score  \
# Model
# NearestCentroid                    0.81               0.76     0.76      0.83
# AdaBoostClassifier                 0.90               0.72     0.72      0.89
# XGBClassifier                      0.91               0.71     0.71      0.90
# PassiveAggressiveClassifier        0.83               0.71     0.71      0.84
# LGBMClassifier                     0.90               0.71     0.71      0.89
# RandomForestClassifier             0.91               0.70     0.70      0.89
# LogisticRegression                 0.90               0.70     0.70      0.89
# LinearDiscriminantAnalysis         0.89               0.70     0.70      0.88
# CalibratedClassifierCV             0.90               0.70     0.70      0.89
# BaggingClassifier                  0.90               0.69     0.69      0.88
# LinearSVC                          0.90               0.69     0.69      0.89
# ...

# %%
# korelasyon işlemleri sonucunda iki özniteliği çıkararak aynı başarı oranını verdi,bu bizim için daha iyi bir durum
# got the same success rate by extracting the two features as a result of the correlation operations, this is a better situation for us

# %%
# en yüksek başarı oranını %91 olarak verdi,optimizasyon işlemiyle bu durum iyileştirilebilir
# gave the highest success rate of 91%, this can be improved with optimization

# %%
#3.yaklaşım ;son olarak aykırı değerler hakkında net bilgimiz olmadığı için Robost işlemi ile ölçekleme yapalım
#3. Approach; Finally, since we do not have clear information about outliers, let's scale with the Robost operation.

# %%
df3=df2.copy()

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4024 entries, 0 to 4023
# Data columns (total 14 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   age                     4024 non-null   int64
#  1   grade                   4024 non-null   object
#  2   regional_node_examined  4024 non-null   int64
#  3   reginol_node_positive   4024 non-null   int64
#  4   survival_months         4024 non-null   int64
#  5   N_race                  4024 non-null   int64
#  6   N_marital_status        4024 non-null   int64
#  7   N_t_stage               4024 non-null   int64
#  8   N_6th_stage             4024 non-null   int64
#  9   N_differentiate         4024 non-null   int64
#  10  N_a_stage               4024 non-null   int64
#  11  N_estrogen_status       4024 non-null   int64
#  12  N_progesterone_status   4024 non-null   int64
#  13  N_status                4024 non-null   int64
# dtypes: int64(13), object(1)
# ...

# %%
df3.head(2)
# Out:
#    age grade  regional_node_examined  reginol_node_positive  survival_months  \
# 0   68     3                      24                      1               60
# 1   50     2                      14                      5               62
#
#    N_race  N_marital_status  N_t_stage  N_6th_stage  N_differentiate  \
# 0       2                 1          0            0                1
# 1       2                 1          1            2                0
#
#    N_a_stage  N_estrogen_status  N_progesterone_status  N_status
# 0          1                  1                      1         0
# 1          1                  1                      1         0

# %%
df3["N_grade"]=le.fit_transform(df3.grade)
df3.head(2)
# Out:
#    age grade  regional_node_examined  reginol_node_positive  survival_months  \
# 0   68     3                      24                      1               60
# 1   50     2                      14                      5               62
#
#    N_race  N_marital_status  N_t_stage  N_6th_stage  N_differentiate  \
# 0       2                 1          0            0                1
# 1       2                 1          1            2                0
#
#    N_a_stage  N_estrogen_status  N_progesterone_status  N_status  N_grade
# 0          1                  1                      1         0        3
# 1          1                  1                      1         0        2

# %%
df3.drop("grade",axis=1,inplace=True)

# %%
df3.head(2)
# Out:
#    age  regional_node_examined  reginol_node_positive  survival_months  \
# 0   68                      24                      1               60
# 1   50                      14                      5               62
#
#    N_race  N_marital_status  N_t_stage  N_6th_stage  N_differentiate  \
# 0       2                 1          0            0                1
# 1       2                 1          1            2                0
#
#    N_a_stage  N_estrogen_status  N_progesterone_status  N_status  N_grade
# 0          1                  1                      1         0        3
# 1          1                  1                      1         0        2

# %%
df3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4024 entries, 0 to 4023
# Data columns (total 14 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   age                     4024 non-null   int64
#  1   regional_node_examined  4024 non-null   int64
#  2   reginol_node_positive   4024 non-null   int64
#  3   survival_months         4024 non-null   int64
#  4   N_race                  4024 non-null   int64
#  5   N_marital_status        4024 non-null   int64
#  6   N_t_stage               4024 non-null   int64
#  7   N_6th_stage             4024 non-null   int64
#  8   N_differentiate         4024 non-null   int64
#  9   N_a_stage               4024 non-null   int64
#  10  N_estrogen_status       4024 non-null   int64
#  11  N_progesterone_status   4024 non-null   int64
#  12  N_status                4024 non-null   int64
#  13  N_grade                 4024 non-null   int64
# dtypes: int64(14)
# ...

# %%
#string değeri sayısal değere dönüştürdük..

# %%
>>> from sklearn.preprocessing import RobustScaler

# %%
X3=df3.drop("N_status",axis=1)
y3=df3["N_status"]

# %%
re=RobustScaler()
X3=re.fit_transform(X3)

# %%
#train-test split

X_train,X_test,y_train,y_test=train_test_split(X3,y3,test_size=0.3,random_state=3)

# %%
clf3= LazyClassifier(verbose=0,ignore_warnings=False, custom_metric=None )
models3,predictions = clf3.fit(X_train, X_test, y_train, y_test)
# Out:
#  24%|██▍       | 7/29 [00:01<00:03,  5.54it/s]
# CategoricalNB model failed to execute
# Negative values in data passed to CategoricalNB (input X)
#  69%|██████▉   | 20/29 [00:04<00:01,  6.49it/s]
# NuSVC model failed to execute
# specified nu is infeasible
#  93%|█████████▎| 27/29 [00:05<00:00,  5.12it/s]
# StackingClassifier model failed to execute
# __init__() missing 1 required positional argument: 'estimators'
# 100%|██████████| 29/29 [00:06<00:00,  4.17it/s]

# %%
models3
# Out:
#                                Accuracy  Balanced Accuracy  ROC AUC  F1 Score  \
# Model
# NearestCentroid                    0.81               0.75     0.75      0.83
# PassiveAggressiveClassifier        0.75               0.73     0.73      0.78
# AdaBoostClassifier                 0.90               0.72     0.72      0.89
# XGBClassifier                      0.91               0.71     0.71      0.90
# LGBMClassifier                     0.90               0.71     0.71      0.89
# BaggingClassifier                  0.90               0.70     0.70      0.89
# LinearDiscriminantAnalysis         0.90               0.70     0.70      0.88
# CalibratedClassifierCV             0.90               0.70     0.70      0.89
# RandomForestClassifier             0.90               0.70     0.70      0.89
# LogisticRegression                 0.90               0.70     0.70      0.89
# LinearSVC                          0.90               0.69     0.69      0.89
# ...

# %%
# en yüksek başarı oranını %91 olarak verdi,optimizasyon işlemiyle bu durum iyileştirilebilir
# gave the highest success rate of 91%, this can be improved with optimization

# %%
# 2.seçenek üzerinde ilerleyelim,önce catboost için başarı oranına bakalım,sonra iki model için optimizasyon işlemi yapalım;
# Let's move on to option 2, first look at the success rate for catboost, then optimize for the two models;

# %%
df2["N_grade"]=le.fit_transform(df2.grade)
df2.drop("grade",axis=1,inplace=True)

# %%
df2.head(1)
# Out:
#    age  regional_node_examined  reginol_node_positive  survival_months  \
# 0   68                      24                      1               60
#
#    N_race  N_marital_status  N_t_stage  N_6th_stage  N_differentiate  \
# 0       2                 1          0            0                1
#
#    N_a_stage  N_estrogen_status  N_progesterone_status  N_status  N_grade
# 0          1                  1                      1         0        3

# %%
X2=df2.drop("N_status",axis=1)
y2=df2["N_status"]

# %%
#train-test split

X_train,X_test,y_train,y_test=train_test_split(X2,y2,test_size=0.3,random_state=3)

# %%
catb=CatBoostClassifier().fit(X_train,y_train)

# %%
y_pred=catb.predict(X_test)
accuracy_score(y_test,y_pred)
# Out:
# 0.9031456953642384

# %%
#xgboost ve Rf için optimizasyon işlemi yapalım;
#Let's optimize for #xgboost and Rf;

# %%
# !pip install optuna

# %%
import optuna
from optuna import Trial,visualization,trial
from optuna.samplers import TPESampler

# %% [markdown]
# <a id="6"></a>
#
# ## 6.RandomForest

# %%
def return_score(param):
    model=RandomForestClassifier(**param).fit(X_train,y_train)
    y_pred=model.predict(X_test)
    acc=accuracy_score(y_test,y_pred)
    return acc

# %%
def objective(trial):
    param={
        "n_estimators":trial.suggest_int("n_estimators",20,1000),
        "criterion":trial.suggest_categorical("criterion",["gini","entropy"]),
        "max_depth":int(trial.suggest_loguniform("max_depth",2,15)),
        "min_samples_split":trial.suggest_int("min_samples_split",2,20),
        "min_samples_leaf":trial.suggest_int("min_samples_leaf",1,20)
    }
    
    return(return_score(param))

# %%
study=optuna.create_study(direction="maximize")
study.optimize(objective,n_trials=250)

# %%
trial.params
#best params
# Out:
# {'n_estimators': 656,
#  'criterion': 'gini',
#  'max_depth': 9.77281097475013,
#  'min_samples_split': 18,
#  'min_samples_leaf': 18}

# %%
trial=study.best_trial
print("accuary:{}".format(trial.value))
# Out:
# accuary:0.9105960264900662

# %%
#%91.05 başarı

# %% [markdown]
# <a id="7"></a>
#
# ## 7.XGBOOST

# %%
def return_score(param):
    model=XGBClassifier(**param).fit(X_train,y_train)
    y_pred=model.predict(X_test)
    acc=accuracy_score(y_test,y_pred)
    return acc

# %%
def objective(trial):
    param={
        "n_estimators":trial.suggest_int("n_estimators",20,500),
        "max_depth":int(trial.suggest_uniform("max_depth",2,12)),
        "reg_alpha":trial.suggest_uniform("reg_alpha",0,6),
        "reg_lambda":trial.suggest_uniform("reg_lambda",0,2),
        "gamma":trial.suggest_uniform("gamma",0,5),
        "learning_rate":trial.suggest_loguniform("learning_rate",0.05,0.5),
        "colsample_bytree":trial.suggest_uniform("colsample_bytree",0.4,0.9),
        "subsample":trial.suggest_uniform("subsample",0.4,0.9)
    }
    return(return_score(param))

# %%
study=optuna.create_study(direction="maximize")
study.optimize(objective,n_trials=200)

# %%
trial=study.best_trial
print("accuary:{}".format(trial.value))
# Out:
# accuary:0.9155629139072847

# %%
#best hyperparametrs
trial.params
# Out:
# {'n_estimators': 206,
#  'max_depth': 2.9485523497860973,
#  'reg_alpha': 3.9395515923741016,
#  'reg_lambda': 0.8666330215886969,
#  'gamma': 0.5122079411767481,
#  'learning_rate': 0.16135236593116617,
#  'colsample_bytree': 0.4583625017207624,
#  'subsample': 0.4954918918091832}

# %%
#başarı oranımız %91,6 en yüksek başarı oranını elde ettik
